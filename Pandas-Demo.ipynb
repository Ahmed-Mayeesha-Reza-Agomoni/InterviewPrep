# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
#dataframe is a collection of rows and columns
df
#the df shown is concatenated to give us a brief overview of the data
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#df.shape(an attribute) will give us a tuple of the number of rows and columns of the data
df.shape
# Out:
# (88883, 85)

# %%
#df.info() is a method which gives us the # of rows and columns
#as well as the datat types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
#In order to see all columns, we can change the settings of jupyter
pd.set_option('display.max_columns',85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.max_columns',4)

# %%
df
# Out:
#        Respondent                                         MainBranch  ...  \
# 0               1             I am a student who is learning to code  ...
# 1               2             I am a student who is learning to code  ...
# 2               3  I am not primarily a developer, but I write co...  ...
# 3               4                     I am a developer by profession  ...
# 4               5                     I am a developer by profession  ...
# ...           ...                                                ...  ...
# 88878       88377                                                NaN  ...
# 88879       88601                                                NaN  ...
# 88880       88802                                                NaN  ...
# 88881       88816                                                NaN  ...
# 88882       88863                                                NaN  ...
#
#                 SurveyLength                  SurveyEase
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
schema_df=pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
pd.set_option('display.max_rows',85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
#to see only the first 5 rows
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#to see the first x no. of rows, write the int value inside the parenthesis of head(x)
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
#to see the last ten rows
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
#video 2

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
#we want to know how many'Yes' or 'No' there are in the Hobbyist column
#unique values
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
#using slicing to get rows and columns
df.loc[0:2,'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
#video 3
#using Respondent ID as index
#we could've used this at the start while reading csv
#df=pd.read_csv('data/survey_results_public.csv',index_col='Respondent')
df.set_index('Respondent',inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df.set_index('Column',inplace=True)
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
#we want to see the full question
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
#we want the index column to be sorted alphabetically
#schema_df.sort_index()
#for descending order, write -> schema_df.sort_index(ascending=False)
#for permanent sorting
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
#data with salary over a certain amount
#first,create a filter
high_salary=(df['ConvertedComp']>70000)
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries=['United States','India','United Kingdom','Germany','Canada']
filt=df['Country'].isin(countries)
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
#we want ppl who work with python
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
#we use a string method to find python
filt=df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
#part 5
df.rename(columns={'ConvertedComp':'SalaryUSD'},inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
#substituting 'Yes' to "True" and "No" to "False"
df['Hobbyist'].map({"Yes":True,"No":False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist']=df['Hobbyist'].replace({"Yes":True,"No":False})
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
#part 7

# %%
#sort by countryname
df.sort_values(by='Country',inplace=True)

# %%
df.head(50)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 39258                          I am a developer by profession      True
# 63129                          I am a developer by profession      True
# 85715                          I am a developer by profession     False
# 50767                          I am a developer by profession     False
# 2782                                                      NaN      True
# 63019                                                     NaN     False
# 6417                   I am a student who is learning to code      True
# 40000                  I am a student who is learning to code      True
# 88731                             I code primarily as a hobby      True
# 48436                          I am a developer by profession     False
# 10746                          I am a developer by profession      True
# 62525                  I am a student who is learning to code      True
# ...

# %%
df['Country'].head(50)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# 86932    Afghanistan
# 85825    Afghanistan
# 7085     Afghanistan
# 7353     Afghanistan
# 87091    Afghanistan
# 58760    Afghanistan
# 74386    Afghanistan
# 29045    Afghanistan
# 51859    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 44403    Afghanistan
# 22450    Afghanistan
# 8149     Afghanistan
# 80926    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 37802    Afghanistan
# 29736    Afghanistan
# 43106    Afghanistan
# 12310    Afghanistan
# 58450    Afghanistan
# ...

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 26340       Afghanistan        NaN
# 86932       Afghanistan        NaN
# 85825       Afghanistan        NaN
# 7085        Afghanistan    14364.0
# 7353        Afghanistan        NaN
# 87091       Afghanistan        NaN
# ...

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=[True, False],inplace=True)

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
#what if i want all of the info 
df.nlargest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      True
# 722                            I am a developer by profession     False
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 28638          0.0
# 722            0.0
# 85715          NaN
# 50767          NaN
# 2782           NaN
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
#this looks for the cols that have numerical values and finds median -> df.median()
#we use median instead of mean as mean is heavily affected by outliers
#count finds the non Na rows
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# True     71257
# False    17626
# Name: count, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 63129    I don't use social media
# 50499                    WhatsApp
# 39258                    Facebook
# 58450                    Facebook
# 7085                    Instagram
#                    ...
# 88062                         NaN
# 88076                         NaN
# 88601                         NaN
# 88802                         NaN
# 88816                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
#Grouping Data
#see specific results based on some column, we use group by
#Grouping -> Split, Apply Function, Combine Results
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
#splitting object
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 2940        I am a developer by profession      True
# 3133        I am a developer by profession      True
# 78960       I am a developer by profession      True
# 3120        I am a developer by profession      True
# 78853       I am a developer by profession     False
# ...                                    ...       ...
# 32801       I am a developer by profession     False
# 32811       I am a developer by profession     False
# 32886       I am a developer by profession     False
# 68604       I am a developer by profession      True
# 33792       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
# ...                                                       ...       ...
# 79312                  I am a student who is learning to code      True
# 79628                          I am a developer by profession     False
# 40151                                                     NaN     False
# 76400       I am not primarily a developer, but I write co...     False
# 30452                  I am a student who is learning to code     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = (df['Country']=='United States')
df.loc[filt]
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 2940        I am a developer by profession      True
# 3133        I am a developer by profession      True
# 78960       I am a developer by profession      True
# 3120        I am a developer by profession      True
# 78853       I am a developer by profession     False
# ...                                    ...       ...
# 32801       I am a developer by profession     False
# 32811       I am a developer by profession     False
# 32886       I am a developer by profession     False
# 68604       I am a developer by profession      True
# 33792       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %%
#The most popular Social Media sites based on a country
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# Twitter                      27
# I don't use social media     27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: proportion, dtype: float64

# %%
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: SalaryUSD, Length: 179, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['SalaryUSD'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
#how many people in each country know how to use python
#Method 1
filt = (df['Country']=='India')
df.loc[filt]
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
# ...                                                       ...       ...
# 79312                  I am a student who is learning to code      True
# 79628                          I am a developer by profession     False
# 40151                                                     NaN     False
# 76400       I am not primarily a developer, but I write co...     False
# 30452                  I am a student who is learning to code     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
#what % of ppl from each country know python
#Steps: a
country_respondents=df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
#b
#total no. of ppl in each country who know python
country_uses_python=country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
#combine more than one series together by using the concat version
python_df=pd.concat([country_respondents, country_uses_python],axis='columns',sort=False)
python_df
# Out:
#                                   count  LanguageWorkedWith
# Country
# United States                     20949               10083
# India                              9061                3105
# Germany                            5866                2451
# United Kingdom                     5737                2384
# Canada                             3395                1558
# ...                                 ...                 ...
# North Korea                           1                   0
# Niger                                 1                   1
# Saint Vincent and the Grenadines      1                   0
# Chad                                  1                   0
# Brunei Darussalam                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'count':"NumRespondents",'LanguageWorkedWith':'NumKnowsPython'},inplace=True)

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython
# Country
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# North Korea                                    1               0
# Niger                                          1               1
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
# Brunei Darussalam                              1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython']= (python_df['NumKnowsPython']/python_df['NumRespondents'])*100
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# North Korea                                    1               0
# Niger                                          1               1
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
# Brunei Darussalam                              1               0
#
#                                   PctKnowsPython
# Country
# United States                          48.131176
# India                                  34.267741
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False,inplace=True)
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Niger                                          1               1
# Dominica                                       1               1
# Turkmenistan                                   7               6
# ...                                          ...             ...
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
# Saint Kitts and Nevis                          1               0
# Malawi                                         2               0
# Brunei Darussalam                              1               0
#
#                                   PctKnowsPython
# Country
# Sao Tome and Principe                 100.000000
# Timor-Leste                           100.000000
# ...

# %%
python_df.head(25)
# Out:
#                            NumRespondents  NumKnowsPython  PctKnowsPython
# Country
# Sao Tome and Principe                   1               1      100.000000
# Timor-Leste                             1               1      100.000000
# Niger                                   1               1      100.000000
# Dominica                                1               1      100.000000
# Turkmenistan                            7               6       85.714286
# Mauritania                              7               5       71.428571
# Guinea                                  3               2       66.666667
# Bahamas                                 3               2       66.666667
# Guyana                                  3               2       66.666667
# Uganda                                 72              47       65.277778
# Iceland                                49              30       61.224490
# Haiti                                   5               3       60.000000
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 63129    Less than 1 year
# 50499                   7
# 39258                   2
# 58450                   6
# 7085                    7
# 22450                   3
# 48436                   2
# 10746                   4
# 8149                    2
# 29736                  10
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['Less than 1 year', '7', '2', '6', '3', '4', '10', '36', '8', nan,
#        '1', '20', '28', '31', '9', '5', 'More than 50 years', '15', '13',
#        '12', '17', '18', '35', '14', '21', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '26',
#        '32', '38', '44', '45', '41', '37', '47', '42', '46', '48', '49',
#        '50'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',51,inplace=True)
df['YearsCode'].unique()
# Out:
# array([0, '7', '2', '6', '3', '4', '10', '36', '8', nan, '1', '20', '28',
#        '31', '9', '5', 51, '15', '13', '12', '17', '18', '35', '14', '21',
#        '25', '11', '19', '22', '23', '40', '39', '30', '43', '27', '33',
#        '29', '24', '34', '16', '26', '32', '38', '44', '45', '41', '37',
#        '47', '42', '46', '48', '49', '50'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
#Reading/Writing from different sources
filt=(df['Country'] == 'India')
india_df=df.loc[filt]
india_df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 80923                              Once a month or more often
# 78265                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
india_df.to_csv('data/modified.csv')

# %%
#tab separated file
india_df.to_csv('data/modified.tsv',sep='\t')

# %%
#Excel files
india_df.to_excel('data/modified.xlsx')

# %%
test=pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
# ...                                                       ...       ...
# 79312                  I am a student who is learning to code      True
# 79628                          I am a developer by profession     False
# 40151                                                     NaN     False
# 76400       I am not primarily a developer, but I write co...     False
# 30452                  I am a student who is learning to code     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
test.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 80923                              Once a month or more often
# 78265                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# ...
